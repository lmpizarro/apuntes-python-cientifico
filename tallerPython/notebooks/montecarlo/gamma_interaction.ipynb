# %%
# -*- coding: utf-8 -*-

'''
moc^2 = rest energy of electron = 511 keV
tita  = angle between incident and scattered gamma rays

planck constant
h = 6.62606957 × 10-34 m2 kg / s
h =  4.135667516 x 10-15 eV*s
c = 299792458 m / s

1 J = 6241509647120.4 MeV
1 eV = 1.602176487E-19 J
1 MeV = 1.602176487E-13 J

E = hc/wavelength
freq = c/wavelength


Compton wavelength: h/mec = 2.43 x 10-12 m comptonWl
me: masa del electron
    9.10938215(45)×10−31 Kg
re: radio del electrón
    2.818x10-15 m


1 barn = 10-28 m2 = 10-24 cm2

'''

class Units:
    comptonWl =  2.43e-12
    c = 299792458
    hmk = 6.62606957e-34
    hev = 4.135667516e-15
    me =  9.10938215e-31
    re = 2.818e-15
    rec = 2.818e-13
    barn = 10e-28 #m2
    re2 = re * re # m2
    

import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

def compton_energy(angle, E): # E en MeV
    return E / (1 + (E/0.511) * (1 - np.cos(angle)))

def kn_kn(angle, E): # E en MeV
    x = 1 - np.cos(angle)
    alpha = E / .511
    y = 1 + alpha * x
    z = y ** (-2)
    w = 1 + np.cos(angle) ** 2
    
    return ((Units.rec ** 2/2) * z * (w + ((alpha * x) ** 2)/y))

def kn(angle, E): # E en Mev
    Er = energy(angle, E)/E
    return ((Units.rec * Er) ** 2)*(Er + 1/Er - np.sin(angle) ** 2) / 2

def kn_knoll(angle, E): #E in Mev
    alpha = E / .511
    x = 1 - np.cos(angle)
    t2 = 1 + np.cos(angle) ** 2
    t3 = t2 / 2
    t4 = 1 / (1 + alpha * x)**2
    t5 = (1 + (alpha**2 * (x**2))/(t2*(1 + alpha * x)))
    
    return ((Units.rec ** 2) * t4 * t3 * t5)
    


#
# A simple algorithm for the transport of gamma rays in a medium
#  Am. J. Phys. 71 ͑1͒, January 2003
#
#
#
# COMPTON-SAMPLING SURFACE FOR MONTE CARLO CALCULATIONS
# IN THE ENERGY RANGE 0.1 TO 100 MeV 
#
# Nuclear Instruments and Methods in Physics Research A254 (1987) 406-412
#
def kn_ni(angle, E): # E en MeV
    x = 1 - np.cos(angle)
    alpha = E / .511
    z = 1 + alpha * x
    cos2 = 1 + np.cos(angle) ** 2
    
    return (Units.rec ** 2/2) * (cos2 + ((alpha * x) ** 2) / z) / (z ** 2)
    

def kn_geant(angle, E):
    x = 1 - np.cos(angle)
    alpha = E / .511
    epsilon = (1+alpha*x)
    sen2 = np.sin(angle)**2
    f1 = epsilon + epsilon**(-1)
    
    return ((Units.rec ** 2)*f1*(1- sen2/f1)) /2

# %%
if __name__ == "__main__":
    angle = np.linspace(0, 2*np.pi, 100)
    ce = compton_energy(angle, 2)
    
    plt.plot(angle, ce)

# %%
if __name__ == "__main__":
    
    E = 10
    dcs_10 = kn_kn(angle, E)
    dcs_11 = kn_knoll(angle, E)
    dcs_12 = kn_ni(angle, E)


    ax = plt.subplot(111, polar=True)
    ax.plot(angle, dcs_10, color='r', linewidth=1)
    ax.set_rmax(dcs_10.max())
    ax.grid(True)

    ax.set_title("dcs kn", va='bottom')
    plt.show()


    # log x and y axis
    plt.subplot(111)
    plt.plot(angle, dcs_10)
    plt.plot(angle, dcs_11)
    plt.plot(angle, dcs_12)

    plt.grid(True)
    plt.title('loglog cs')   

    plt.show()

# %% [markdown]
# ## Photon Cross Section
#
# #### Energy|Cohe_Scat|Inco_Scat|Pho_Absr|Nuc_PrPrd|Elc_PrPrd|Tot_wCohe|Tot_sCohe|
#
# Photon cross section data for a single element, compound, or mixture [link](http://physics.nist.gov/PhysRefData/Xcom/html/xcom1-t.html)
#
# ![Nist](nist-pl-black.gif)
#
#
# ### Datos para el INa
#
# * #### I: Z = 53 %W 0.84627 dens 4.93 g/cm3
# * #### Na: Z = 11 %W 0.153373 dens 0.97 g/cm3
#
# * #### NaI: dens = 4.3224 g/cm3

# %%
densNa = 0.97
pcNa = 0.15373
densI  = 4.93
pcI = 0.84627
densNaI = densNa * pcNa + densI * pcI
print(densNaI)
# Out:
# 4.321229199999999

# %%
import csv

rows=[]

with open('xcom_ina.pl') as csvfile:
    reader = csv.DictReader(csvfile,delimiter='|')
    for row in reader:
        # http://stackoverflow.com/questions/14813396/python-elegant-way-to-delete-empty-lists-from-python-dict
        rows.append({k:v for k,v in row.items() if v})

reader.fieldnames = reader.fieldnames[:-1]        
n_fields = len(reader.fieldnames)
n_data = len(rows)

import numpy as np

cs = np.zeros(n_fields * n_data).reshape(n_data, n_fields)

i = 0
for r in rows:
    cs[i] = np.asarray([r[f] for f in reader.fieldnames])
    i = i + 1

# log x and y axis
plt.subplot(111)
for i in range(1, n_fields):
    plt.loglog(cs[:,0], cs[:,i], basex=10)

plt.grid(True)
plt.title('loglog cs')   

plt.show()

# %% [markdown]
# ##  Total

# %%
# log x and y axis
plt.subplot(111)
plt.loglog(cs[:,0], cs[:,7], basex=10)

plt.grid(True)
plt.title('loglog cs')   

plt.show()

# %% [markdown]
# ## Mean Free Path

# %%
mfp = 1/(cs[:,7] * densNaI)

# log x and y axis
plt.subplot(111)
plt.loglog(cs[:,0], mfp, basex=10)

plt.grid(True)
plt.title('loglog cs')   

plt.show()
print(mfp.min(), mfp.max(), mfp.mean())
# Out:
# 2.92007110615e-05 6.66519686527 2.70212609335

# %% [markdown]
# ## Absorción fotoeléctrica

# %%
# log x and y axis
plt.subplot(111)
plt.loglog(cs[:,0], cs[:,3], basex=10)

plt.grid(True)
plt.title('loglog cs')   

plt.show()

# %% [markdown]
# ## Producción de pares

# %%
# log x and y axis
plt.subplot(111)
#plt.loglog(cs[:,0], cs[:,5], basex=10)
plt.loglog(cs[:,0], cs[:,4], basex=10)

#lt.loglog(cs[:,0], cs[:,5]+cs[:,4], basex=10)


plt.grid(True)
plt.title('loglog cs')   

plt.show()

# %% [markdown]
# ## Incoherent scatering - Compton

# %%
# log x and y axis
plt.subplot(111)
plt.loglog(cs[:,0], cs[:,2], basex=10)

plt.grid(True)
plt.title('loglog cs')   

plt.show()

# %% [markdown]
# ## Cálculo de secciones parciales y totales

# %%
mu_total = cs[:,4] + cs[:,3] + cs[:,2] # pares + photo + compton

p_photo_e = cs[:,3] / mu_total
p_photo_compton_e = (cs[:,3] + cs[:,2]) / mu_total

# log x and y axis
plt.subplot(111)
plt.loglog(cs[:,0], p_photo_e, basex=10)
plt.loglog(cs[:,0], p_photo_compton_e)

plt.grid(True)
plt.title('loglog cs')   

plt.show()

# %% [markdown]
# ## Interpolación para determinar secciones en función de la energía

# %%
N = 1000000
R = np.random.random(size = N)
E = 1.02205 # Mev
p_photo_compt = np.interp(E, cs[:,0], p_photo_compton_e)
p_photo = np.interp(E, cs[:,0], p_photo_e)

a = R <= p_photo 

b = R > p_photo
c = R <= p_photo_compt
d = b & c
e = R > p_photo_compt
n_compton = d.sum()
n_photo = a.sum()
n_pair = e.sum()

print("photo", n_photo)
print("compton", n_compton)
print("pair",  n_pair)
# Out:
# photo 58509
# compton 941491
# pair 0

# %%
# aceptacion klein-nishina
# solid angle
N = n_compton
angle_c = np.arccos(1 - 2 * np.random.random(size=N)) 

#cross section
r0 = 2.818e-13 #cm
cross_section = (r0 ** 2) * np.random.random(size = N) / 2

kn = kn_knoll(angle_c, 1)

accept = (cross_section < kn)

print(accept.sum())
# Out:
# 111212

# %%
# interpolar
# >>> xp = [1, 2, 3]
# >>> fp = [3, 2, 0]
# >>> np.interp(2.5, xp, fp)
lambda_ = np.interp(1, cs[:,0], mfp)

N = 10000
s = - lambda_ * np.log(np.random.random(size=N))
u = 2*np.random.random(size=N) - 1

x = s *u

print(x[x>5].size)
print(x[x<0].size)
# Out:
# 550
# 5008

# %%
N = 80
E = .661
H = 5
acum_photo = 0
acum_no_interactuan = 0

# E ang_p ang_a x
Estado = np.zeros(4*N).reshape(4, N)
Estado[0:1, :] +=.661   # asigno la energía

mfp0 = np.interp(Estado[0:1,:], cs[:,0], mfp)

rs = np.random.random(N)

# determino el recorrido
Estado[3:4,:] = - mfp0 * np.log(rs)

no_interactuan = Estado[3:4,] > H
acum_no_interactuan += no_interactuan.sum()
Estado = np.delete(Estado, np.nonzero(no_interactuan[0])[0], 1)

p_photo = np.interp(Estado[0:1,:], cs[:,0], p_photo_e)
rp = np.random.random(Estado.shape[1])
hacen_photo = rp <= p_photo
acum_photo += hacen_photo.sum()
Estado = np.delete(Estado, np.nonzero(hacen_photo[0])[0], 1)

print (acum_photo, acum_no_interactuan, Estado.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-308-8e06af8e6da2> in <module>()
#       9 Estado[0:1, :] +=.661   # asigno la energía
#      10
# ---> 11 mfp0 = np.interp(Estado[0:1,:], cs[:,0], mfp)
#      12
#      13 rs = np.random.random(N)
#
# NameError: name 'cs' is not defined

# %% [markdown]
# ## Algoritmo de Aceptación y rechazo klein-nishina
#
# ### v 01

# %%
E = 1

N = 100

accept_angle = np.empty(0)

while N > 0:
    rangle = np.random.random(size=N) * 2 * np.pi
    rdens  = np.random.random(size=N)


    dcs_10 = kn_kn(rangle, E)/ (Units.rec **2)
    
    accept = dcs_10 < rdens

    no_accept = np.invert(accept)

    N = no_accept.sum()


    accept_angle = np.append(accept_angle, rangle[accept])
    
accept_energy = compton_energy(accep_angle, E)

# %%
N = 1000

estado = np.zeros(3*N).reshape(3,N)

estados_aceptados = np.empty((3,0))

# asignacion de energías
estado[0:1, :] = 1.99*np.random.random(size=N) + 0.01

# asigno a estado a un temporario
estado_temp = estado

# generacion de ángulos aleatorios
angulos = np.random.random(size = estado_temp.shape[1]) * 2 * np.pi

# asignacion de ángulos aleatorios 
estado_temp[1:2] = angulos

# generacion de densidades aleatorias
densidades  = np.random.random(size = estado_temp.shape[1])

# saco energía de matríz de estado
energia = estado_temp[0:1,:]

# se calcula la densidad con klein nishina
dcs_10 = kn_kn(angulos, energia )/ (Units.rec **2)

# determino las posiciones aceptadas
accept = dcs_10 < densidades
# guardo esas posiciones aceptadas
estado_temp[2:3,:] = accept

aceptados = estado_temp[0:3,(estado_temp[2:3] == 1)[0]]

estados_aceptados = np.hstack((estados_aceptados, aceptados))

siguen_compt = estado_temp[0:3, (estado_temp[2:3] == 0)[0]] 

# acá siguen_compt - > estado

siguen_compt.shape[1], estados_aceptados.shape, siguen_compt.shape, aceptados.shape
# Out:
# (327, (3, 673), (3, 327), (3, 673))

# %%
N = 1000000

estado = np.zeros(3*N).reshape(3,N)
# asignacion de energías
estado[0:1,:] = 1.99*np.random.random(size=N) + 0.01

estado_temp = np.copy(estado)
estados_aceptados = np.empty((3,0))
estats = np.zeros(0)

Ninit = N
while N > 0:
    # generacion de ángulos aleatorios
    angulos = np.random.random(size=estado_temp.shape[1]) * 2 * np.pi

    # asignacion de ángulos aleatorios 
    estado_temp[1:2] = angulos

    # generacion de densidades aleatorias
    densidades  = np.random.random(size=estado_temp.shape[1])

    # saco energía de matríz de estado
    energia = estado_temp[0:1,:]

    # se calcula la densidad con klein nishina
    dcs_10 = kn_kn(angulos, energia )/ (Units.rec **2)

    # determino las posiciones aceptadas
    accept = dcs_10 < densidades
    # guardo esas posiciones aceptadas
    estado_temp[2:3,:] = accept

    aceptados = estado_temp[0:3,(estado_temp[2:3] == 1)[0]]

    estados_aceptados = np.hstack((estados_aceptados, aceptados))

    siguen_compt = estado_temp[0:3, (estado_temp[2:3] == 0)[0]] 

    # acá siguen_compt - > estado_temp
    N = siguen_compt.shape[1]
    estats = np.append(estats, N)
    # asigno a estado a un temporario
    estado_temp = siguen_compt
    if N < 0.02 * Ninit:
        break

# %%
plt.plot(estats)

# %%
print(estats.min(), estats.max(), estats.sum(), estats[0:10].sum(), estats.size)
# Out:
# 19631.0 317480.0 493003.0 493003.0 4

# %%
print(estats)
# Out:
# [ 317433.  111812.   44159.   19835.    9897.]

# %% [markdown]
# # Sine and cosine of random angle in 2D

# %%
N = 100
u1 = np.random.random(size=N)
u2 = np.random.random(size=N)
v1 = 2 * u1 - 1
v2 = u2
r2 = v1 ** 2 + v2 ** 2

S = 2 * v1 * v2 / r2
C = (v1 ** 2 - v2 ** 2) / r2
plt.plot (S)
plt.plot(C)
