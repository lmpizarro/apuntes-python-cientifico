# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ### matplotlib Plotting Cookbook de  Alexandre Devert

# %%
X = range(100)
Y = [value ** 2 for value in X]
plt.plot(X, Y)
plt.show()

# %% [markdown]
# python plot.py

# %% [markdown]
# ## Usar numpy

# %%
X = np.linspace(0, 2 * np.pi, 100)
Y = np.sin(X)
plt.plot(X, Y)
plt.show()

# %% [markdown]
# #### Idéntico resultado sin numpy

# %%
import math

T = range(100)
X = [(2 * math.pi * t) / len(T) for t in T]
Y = [math.sin(value) for value in X]
plt.plot(X, Y)
plt.show()

# %%
X = np.linspace(-3, 2, 200)
Y = X ** 2 - 2 * X + 1.
plt.plot(X, Y)
plt.show()

# %% [markdown]
# ## Graficar varias curvas

# %%
X = np.linspace(0, 2 * np.pi, 100)
X = np.linspace(0, 2 * np.pi, 100)
Ya = np.sin(X)
Yb = np.cos(X)
plt.plot(X, Ya)
plt.plot(X, Yb)
plt.show()

# %%
def plot_slope(X, Y):
    Xs = X[1:] - X[:-1]
    Ys = Y[1:] - Y[:-1]
    plt.plot(X[1:], Ys / Xs)
    
X = np.linspace(-3, 3, 100)
Y = np.exp(-X ** 2)

plt.plot(X, Y)
plot_slope(X, Y)
plt.show()

# %% [markdown]
# ## Graficar curvas de archivos de datos

# %%
X, Y = [], []

for line in open('datos.txt', 'r'):
  values = [float(s) for s in line.split()]
  X.append(values[0])
  Y.append(values[1])
    
plt.plot(X, Y)
plt.show()

# %%
with open('datos.txt', 'r') as f:
  X, Y = zip(*[[float(s) for s in line.split()] for line in f])

plt.plot(X, Y)
plt.show()

# %%
data = np.loadtxt('datos.txt')

plt.plot(data[:,0], data[:,1])
plt.show()

# %%
data = np.loadtxt('datos2.txt')

for column in data.T:
    plt.plot(data[:,0], column)
    
    
plt.show()

# %% [markdown]
# ## Graficar puntos

# %%
data = np.random.rand(1024, 2)
plt.scatter(data[:,0], data[:,1])
plt.show()

# %% [markdown]
# ## Gráficos de barras

# %%
data = [5., 25., 50., 20.]
plt.bar(range(len(data)), data)
plt.show()

# %% [markdown]
# #### Controlando el ancho de las barras

# %%
data = [5., 25., 50., 20.]
plt.bar(range(len(data)), data, width = .5)
plt.show()

# %% [markdown]
# #### Barras horizontales

# %%
data = [5., 25., 50., 20.]
plt.barh(range(len(data)), data)
plt.show()

# %% [markdown]
# ## Dibujar gráficos de barras múlitples

# %%
data = [[5., 25., 50., 20.],
[4., 23., 51., 17.],
[6., 22., 52., 19.]]
X = np.arange(len(data[0]))
plt.bar(X + 0.00, data[0], color = 'b', width = 0.25)
plt.bar(X + 0.25, data[1], color = 'g', width = 0.25)
plt.bar(X + 0.50, data[2], color = 'r', width = 0.25)
plt.show()

# %% [markdown]
# # Trabajar con anotaciones

# %% [markdown]
# ## Agregar un título

# %%
X = np.linspace(-4, 4, 1024)
Y = .25 * (X + 4.) * (X + 1.) * (X - 2.)
plt.title('A polynomial')
plt.plot(X, Y, c = 'k')
plt.show()

# %% [markdown]
# ## Agregar un texto a cada eje

# %%
X = np.linspace(-4, 4, 1024)
Y = .25 * (X + 4.) * (X + 1.) * (X - 2.)
plt.title('Power curve for airfoil KV873')
plt.xlabel('Air speed')
plt.ylabel('Total drag')
plt.plot(X, Y, c = 'k')
plt.show()

# %% [markdown]
# ## Agregar título en latex

# %%
X = np.linspace(-4, 4, 1024)
Y = .25 * (X + 4.) * (X + 1.) * (X - 2.)
plt.title('$f(x)=\\frac{1}{4}(x+4)(x+1)(x-2)$')
plt.plot(X, Y, c = 'k')
plt.show()

# %% [markdown]
# # Grabando gráficos en disco

# %% [markdown]
# ## Generar un archivo png

# %%
X = np.linspace(-10, 10, 1024)
Y = np.sinc(X)
plt.plot(X, Y)
plt.savefig('sinc.png', c = 'k')

# %% [markdown]
# ## Graficación 2D

# %%
# creación de un array con una función
b = np.random.normal(1,.1, size= 30*30).reshape(30,30)
plt.pcolormesh (b)

# %%
# aplica un recorte a los valores menor a  1 y grafica
c = np.where(b < 1, 0, b)
plt.pcolormesh (c)

# %%
c=np.where(c >=1, 1, c)
plt.pcolormesh (c)

# %% [markdown]
# ### La función np.meshgrid

# %% [markdown]
# Ver [link](https://www.safaribooksonline.com/library/view/python-for-data/9781449323592/ch04.html)

# %%
# La función np.meshgrid toma 2 arrays 1D y produce 2 matríces 2D
# correspondiente a todos los pares (x,y) en los 2 arreglos

points = np.arange(-5, 5, 0.01)
xs, ys = np.meshgrid(points, points)
z = np.sqrt(xs ** 2 + ys ** 2)
plt.imshow(z, cmap=plt.cm.gray); plt.colorbar()
